# %% [markdown]
# ## Machine Learning: Train model and make predictions

# %%
# Loading libraries
import numpy as np
import pandas as pd
import os

from sklearn.ensemble import RandomForestRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Loading data-sets

# %%
# setting paths
data_dir = os.path.abspath('/content/drive/My Drive/Projects/YapAiTek_Challenge/_data')
train_data_fp = os.path.join(data_dir, 'X_train_final.npy')
y_true_fp = os.path.join(data_dir, 'y_train_final.npy')
test_data_fp = os.path.join(data_dir, 'X_test_final.npy')
test_csv_data_fp = os.path.join(data_dir, 'test.csv')

# %%
# Loading data-sets
traindata = np.load(train_data_fp)
target = np.load(y_true_fp)
testdata = np.load(test_data_fp)
test_df = pd.read_csv(test_csv_data_fp)

# %%
test_df.tail(2)
# Out:
#         Unnamed: 0  ... Temperature in Montreal during episode
# 154163      154164  ...                                 22.675
# 154164      154165  ...                                 16.825
#
# [2 rows x 19 columns]

# %%
id = test_df.loc[:, 'Unnamed: 0'].values

# %% [markdown]
# ### Train RandomForest estimator and make predictions

# %%
model = RandomForestRegressor(n_estimators=150, max_depth=None, min_samples_leaf=2, max_features=0.5, n_jobs=-1)

# %%
# %%time

model.fit(traindata, target)
# Out:
# CPU times: user 9min, sys: 3.48 s, total: 9min 3s
# Wall time: 4min 36s
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=0.5, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=150, n_jobs=-1, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
preds = model.predict(testdata)

# %% [markdown]
# ### Save predictions to disk as cvs

# %%
output = pd.DataFrame({'id': id, 'Market Share_total': preds})
output.tail()
# Out:
#             id  Market Share_total
# 154160  154161            1.499982
# 154161  154162            1.341439
# 154162  154163            1.890372
# 154163  154164            1.298266
# 154164  154165            1.383629

# %%
output.to_csv(data_dir+'/predictions.csv')
